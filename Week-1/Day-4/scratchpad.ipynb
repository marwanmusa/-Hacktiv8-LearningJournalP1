# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('gene_expression.csv')
df.head()
# Out:
#    Gene One  Gene Two  Cancer Present
# 0       4.3       3.9               1
# 1       2.5       6.3               0
# 2       5.7       3.9               1
# 3       6.1       6.2               0
# 4       7.4       3.4               1

# %%
df.shape
# Out:
# (3000, 3)

# %%
df['Cancer Present'].value_counts()
# Out:
# 1    1500
# 0    1500
# Name: Cancer Present, dtype: int64

# %%
sns.scatterplot(x='Gene One', y='Gene Two', data=df, hue='Cancer Present', style='Cancer Present', alpha = 0.9)
# Out:
# <AxesSubplot:xlabel='Gene One', ylabel='Gene Two'>

# %%
sns.scatterplot(x='Gene One', y='Gene Two', data=df, hue='Cancer Present', style='Cancer Present')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X = df.drop('Cancer Present', axis = 1)
y = df['Cancer Present']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=45    )

# %%
scaler = StandardScaler()
scaler.fit(X_train)

scaled_X_train = scaler.transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %%
scaled_X_train
# Out:
# array([[ 0.03459731,  2.3863981 ],
#        [-0.2936603 , -0.23592591],
#        [ 0.74582214, -0.46902138],
#        ...,
#        [-1.66140036,  0.57990822],
#        [-0.67662752,  0.92955142],
#        [-1.16901394,  1.22092076]])

# %%
df1 = pd.Dataframe(data=)
